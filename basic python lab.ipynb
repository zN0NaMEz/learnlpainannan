# %% [markdown]
# # Code

# %% [markdown]
# ## Data type

# %% [markdown]
# จงเขียน code เพื่อให้ได้ output ตามที่รันไว้

# %%
#int, float, complex
# print your studentID as int
a = 67011018
print(a)
print(type(a))
b = 670110.18
print(b)
print(type(b))
#string 
c = "67011018"
print(c)
print(type(c))
#print a b c 
print(a ,b, c)
#print a b c with - seperate
print(a ,b, c, sep='-')
# Out:
# 67011018
# <class 'int'>
# 670110.18
# <class 'float'>
# 67011018
# <class 'str'>
# 67011018 670110.18 67011018
# 67011018-670110.18-67011018

# %% [markdown]
# ### Polymorphic

# %%
for i in range(0, 200):
    print(67011018)
# Out:
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# 67011018
# ...

# %%
n = input("input your studentID")
#นำค่าที่กรอกมายกกำลัง 3 และแสดงผลโดยใช้คำสั่ง print เพียงครั้งเดียว โดยแสดงผลให้เหมือนทุกตัวอักษรและการเว้น
result = 67011018 ** 3
print()

# %% [markdown]
# ### String

# %%
s = " Hello World "
#ต้องการคำว่า World ต้อง print ยังไง
print()
#ต้องการคำว่า HlWl จาก s โดยใช้ print ครั้งเดียวโดยใช้ slicing [::] เท่านั้น
print() 
#s มีขนาดเท่าไหร่
print()
# Out:
# World
# HlWl
# 13

# %% [markdown]
# ### Method Chaining

# %%
# input เป็น เว้นช่องว่างตามด้วยชื่อ นามสกุล physiciot เว้นช่องว่าง แล้ว enter
s = input (" ชื่อ นามสกุล ภาควิชาตัวพิมพ์เล็ก \n")
# เปลี่ยน input เป็นตัวพิมพ์ใหญ่ทั้งหมด ตัด white space ข้างน้าและข้างหลัง
# แล้วให้หาตำแหน่ง "PHYSIC" (ตัวพิมพ์ใหญ่) โดยใช้ method chaining เท่านั้น
print()
# Out:
#  ชื่อ นามสกุล ภาควิชาตัวพิมพ์เล็ก
#  pikulkaew tangtisanon physiciot
# 22

# %% [markdown]
# ### If/ If...else

# %% [markdown]
# เขียนโปรแกรมคำสั่ง if-elif-else เพื่อตรวจสอบอายุที่ผู้ใช้ป้อนเข้ามา:
#
# ถ้าอายุ age มากกว่าหรือเท่ากับ 18, จะแสดงผลลัพธ์ "You are an adult"
# ถ้าอายุ age อยู่ระหว่าง 13-17, จะแสดงผลลัพธ์ "You are a teenager."
# ถ้าอายุ age อยู่ระหว่าง 7-12, จะแสดงผลลัพธ์ "You are a pre-teenager."
# ถ้าอายุ age น้อยกว่า 7, จะแสดงผลลัพธ์ "You are a child"

# %%
age = int(input("Enter your age: "))
# Out:
# Enter your age: 13
# You are a teenager.

# %% [markdown]
# ### while

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อรับตัวเลขจากผู้ใช้จนกว่าจะป้อนค่าเลขที่น้อยกว่า 10 และแสดงผลจำนวนครั้งที่ป้อนเลข

# %%
print("Number of attempts:", count)
# Out:
# Enter a number: 20
# Enter a number: 30
# Enter a number: -5
# Number of attempts: 2

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อรับตัวเลขจากผู้ใช้ ถ้าผู้ใช้ป้อนค่าเป็นเลขคู่ให้แสดงข้อความ "เลขคู่" และถ้าผู้ใช้ป้อนค่าเป็นเลขคี่ให้แสดงข้อความ "เลขคี่" หยุดโปรแกรมโดยป้อน 0 ให้ใช้ลูป while-else

# %%
# Out:
# Enter a number (0 to quit): 23
# Odd number
# Enter a number (0 to quit): 96
# Even number
# Enter a number (0 to quit): 66
# Even number
# Enter a number (0 to quit): 0

# %% [markdown]
# ### for

# %% [markdown]
# เขียนสูตรคูณโดยใช้ for loop โดยนำตัวที่รับมาคูณตั้งแต่ 1 ถึง 12

# %%
num = input("สูตรคูณแม่ ")
# Out:
# สูตรคูณแม่ 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 6 x 11 = 66
# 6 x 12 = 72

# %% [markdown]
# ### List[]

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อรับจำนวนเต็มบวกจากผู้ใช้ จำนวนเต็มที่รับเข้ามาจะแสดงในลักษณะ List และหยุดรับข้อมูลเมื่อผู้ใช้ป้อนค่าเป็น -1 โดยใช้ลิสต์ (list) เท่านั้นในการเก็บข้อมูลที่รับเข้ามา

# %%
numbers = []
# Out:
# Enter a number (-1 to quit): 5
# Enter a number (-1 to quit): 6
# Enter a number (-1 to quit): -10
# Enter a number (-1 to quit): -20
# Enter a number (-1 to quit): -1
# Numbers: [5, 6, -10, -20]

# %% [markdown]
# ###  List Mutable []
# *add:* append(), extend(), insert(), +

# %%
color = ["red", "green", "blue"]
# เพิ่มสี white ไปยังตำแหน่งสุดท้าย

print(color)
#เพิ่ม 2 สี "pink", "orange" เข้าไปยัง color โดยห้ามทำ append ทีละครั้ง
new_color = ["pink", "orange"]

print(color)
#เพิ่มสี "black" ไปหลังสี green

print(color)
#เปลี่ยนจากสี white เป็นสี silver

print(color)
# นำ list สีที่มีอยู่ color มารวมกับ list สีใหม่ new_color2
new_color2 = ["grey", "bluesky", "gold"]
print()
# Out:
# ['red', 'green', 'blue', 'white']
# ['red', 'green', 'blue', 'white', 'pink', 'orange']
# ['red', 'green', 'black', 'blue', 'white', 'pink', 'orange']
# ['red', 'green', 'black', 'blue', 'silver', 'pink', 'orange']
# ['red', 'green', 'black', 'blue', 'silver', 'pink', 'orange', 'grey', 'bluesky', 'gold']

# %% [markdown]
# *delete :* remove(), pop(), del, clear()

# %%
print(color)
#pop blue ออกมาเก็บไว้ใน color_pop
color_pop= 
print("color is" , color)
print("pop_color is ", color_pop)
#ลบสี green ออกจาก color
color.
print("color after remove green" , color)
# Out:
# ['red', 'green', 'black', 'blue', 'silver', 'pink', 'orange']
# color is ['red', 'green', 'blue', 'silver', 'pink', 'orange']
# pop_color is  black
# color after remove green ['red', 'blue', 'silver', 'pink', 'orange']

# %%
#จงเขียนโปรแกรมลบสี purpleโดยไม่ให้เกิด error หากไม่พบลบไม่ได้ให้ขึ้น can not find
# Out:
# can not find

# %% [markdown]
# ### Tuple Immutable ()

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อรับชื่อผลไม้จากผู้ใช้ จำนวนชื่อผลไม้ที่รับเข้ามาไม่เกิน 3 ชื่อ และแสดงผลลัพธ์เป็นลำดับของชื่อผลไม้ที่ผู้ใช้ป้อนเข้ามา โดยใช้ทูเพิล (tuple) เก็บข้อมูลที่รับเข้ามา

# %%
fruits = ()



print("Fruits:", fruits)
# Out:
# Enter a fruit: apple
# Enter a fruit: banana
# Enter a fruit: coconut
# Fruits: ('apple', 'banana', 'coconut')

# %% [markdown]
# ### Dictionary Mutable  {"key" : "value"}

# %%
# การสร้าง
dbook_info = {'title' : 'Python Basics',
'price' : 39.99,
'year' : 2021,
'authors' : ( 'D.Amos', 'D.Bader','J.Jablonski', 'F.Heisler')
}
customer = dict ([ 
    ('name', 'pikulkaew tangtisanon'),
    ('tel', '0812345678' )
])

customer2 = dict(name='pikulkaew tangtisanon', tel='0812345678')
# การเข้าถึงข้อมูล key, get()
# ต้องการข้อมูล dbook_info ทั้งหมด
print()
#ต้องการข้อมูล customer และ customer2
print()
print()
# ต้องการข้อมูล authors ใน dbook_info 
print("the author are ")
# ต้องการข้อมูล title ใน dbook_info 
print("the title is ")

# เปลี่ยนเบอร์โทร(tel)ลูกค้า(customer)เป็น 5678

#เพิ่มงานอดิเรกลูกค้า(hobby) เป็น tennis

print(customer)
# เปลี่ยนงานอดิเรก(hobby) เป็น golf

print(customer)
#การลบงานอดิเรกทิ้ง

print(customer)
# pop เบอร์โทรลูกค้ามาใช้งานต่อโดยให้รับด้วยตัวแปร phone

print("phone =", phone)
# Out:
# {'title': 'Python Basics', 'price': 39.99, 'year': 2021, 'authors': ('D.Amos', 'D.Bader', 'J.Jablonski', 'F.Heisler')}
# {'name': 'pikulkaew tangtisanon', 'tel': '0812345678'}
# {'name': 'pikulkaew tangtisanon', 'tel': '0812345678'}
# the author are  ('D.Amos', 'D.Bader', 'J.Jablonski', 'F.Heisler')
# the title is  Python Basics
# {'name': 'pikulkaew tangtisanon', 'tel': '5678', 'hobby': 'tennis'}
# {'name': 'pikulkaew tangtisanon', 'tel': '5678', 'hobby': 'golf'}
# {'name': 'pikulkaew tangtisanon', 'tel': '5678'}
# phone = ('tel', '5678')

# %% [markdown]
# ### Dictionary Loop

# %%
sport = dict(soccer=11, rugby=15, volleyball=6, basketball=5, polo=4, softball=9)
print(sport)
# loop โดย keys
for i in 
    print("key : ")
#loop โดย values
for i in 
    print("value 1: ")
#loop โดย values
for i in 
    print("value 2: ")
#loop โดย items ได้ tuple
for i in :
    print()
    
#loop โดย items unpack
for  in :
    print()
# Out:
# {'soccer': 11, 'rugby': 15, 'volleyball': 6, 'basketball': 5, 'polo': 4, 'softball': 9}
# key :  soccer
# key :  rugby
# key :  volleyball
# key :  basketball
# key :  polo
# key :  softball
# value 1:  11
# value 1:  15
# value 1:  6
# value 1:  5
# value 1:  4
# value 1:  9
# value 2:  11
# value 2:  15
# value 2:  6
# value 2:  5
# value 2:  4
# value 2:  9
# ('soccer', 11)
# ('rugby', 15)
# ('volleyball', 6)
# ('basketball', 5)
# ('polo', 4)
# ('softball', 9)
# soccer 11
# rugby 15
# volleyball 6
# basketball 5
# polo 4
# softball 9

# %% [markdown]
# ### Cloning Dictionary

# %%
#copy ข้อมูลจากตัวแปร sport ลงมาในตัวแปร sport2

#popitem ออกจาก sport2

print(sport)
print(sport2)
# Out:
# {'soccer': 11, 'rugby': 15, 'volleyball': 6, 'basketball': 5, 'polo': 4, 'softball': 9}
# {'soccer': 11, 'rugby': 15, 'volleyball': 6, 'basketball': 5, 'polo': 4}

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อจัดเก็บข้อมูลสมาชิก โดยใช้พจนานุกรม (dictionary) เก็บข้อมูลเกี่ยวกับชื่อ, เพศ, และอายุของสมาชิก กำหนดให้โปรแกรมรับข้อมูลสมาชิกจากผู้ใช้และแสดงผลข้อมูลสมาชิกทั้งหมดที่ถูกจัดเก็บ

# %%
members = {}
# Out:
# Enter member's name: kaew
# Enter member's gender: female
# Enter member's age: 30
# Do you want to add another member? (yes/no): yes
# Enter member's name: shota
# Enter member's gender: male
# Enter member's age: 5
# Do you want to add another member? (yes/no): no
# Member List:
# Name: kaew
# Gender: female
# Age: 30
#
# Name: shota
# Gender: male
# Age: 5

# %% [markdown]
# ### Sets {}

# %% [markdown]
# ให้เขียนโปรแกรมเพื่อรับจำนวนเต็มบวกจากผู้ใช้ จำนวนเต็มที่รับเข้ามาจะถูกเก็บในเซต (set) โดยให้โปรแกรมหยุดรับข้อมูลเมื่อผู้ใช้ป้อนค่าซ้ำ และแสดงผลข้อมูลทั้งหมดในเซตที่ถูกจัดเก็บ

# %%
numbers = set()
# Out:
# Enter a number: 20
# Enter a number: 30
# Enter a number: -10
# Enter a number: 0
# Enter a number: -1
# Enter a number: 20
# Duplicate number found!
# Numbers in the set:
# 0
# 20
# -10
# 30
# -1

# %%
set_A = {1, 2, 3, 4, 5}
set_B = {4, 5, 6, 7, 8}
# แสดงผลลัพธ์: {1, 2, 3, 4, 5, 6, 7, 8}


print() 

# แสดงผลลัพธ์: {4, 5}


print()  

# แสดงผลลัพธ์: {1, 2, 3}


print() 

# แสดงผลลัพธ์: {1, 2, 3, 6, 7, 8}

print()
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 6, 7, 8}
